# %%
#!/usr/bin/env python

# import blockchain library
from blockchain import blockexplorer

# get a particular block
block = blockexplorer.get_block('0000000000000000002e90b284607359f3415647626447643b9b880ee00e41fa')
print("Block Height: %s\n" % block.height)
print("Block Fee: %s\n" % block.fee)
print("Block size: %s\n" % block.size)
print("Block transactions: %s\n" % block.transactions)
# Out:
# Block Height: 536081
#
# Block Fee: 6291561
#
# Block size: 1141189
#
# Block transactions: [<blockchain.blockexplorer.Transaction object at 0x00000162C70A1748>, <blockchain.blockexplorer.Transaction object at 0x00000162C70A1780>, <blockchain.blockexplorer.Transaction object at 0x00000162C70A1860>, <blockchain.blockexplorer.Transaction object at 0x00000162C70A1940>, <blockchain.blockexplorer.Transaction object at 0x00000162C70A1A20>, <blockchain.blockexplorer.Transaction object at 0x00000162C70A1B00>, <blockchain.blockexplorer.Transaction object at 0x00000162C70A1BE0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70A1CC0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70A1DA0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5080>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5160>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5240>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5320>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5400>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5550>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5668>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5780>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5898>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D59B0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5AC8>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5BE0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70D5DD8>, <blockchain.blockexplorer.Transaction object at 0x00000162C70DB2B0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70DB390>, <blockchain.blockexplorer.Transaction object at 0x00000162C70DB4A8>, <blockchain.blockexplorer.Transaction object at 0x00000162C70DB588>, <blockchain.blockexplorer.Transaction object at 0x00000162C70DB630>, <blockchain.blockexplorer.Transaction object at 0x00000162C70DB710>, <blockchain.blockexplorer.Transaction object at 0x00000162C70DB828>, <blockchain.blockexplorer.Transaction object at 0x00000162C70DB940>, <blockchain.blockexplorer.Transaction object at 0x00000162C70DBA20>, <blockchain.blockexplorer.Transaction object at 0x00000162C70DBB00>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E1780>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E18D0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E19B0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E1AC8>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E1BE0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E1C88>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E1D68>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E1E10>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E1EF0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E1FD0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E80B8>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E8240>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E8358>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E8438>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E8518>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E85F8>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E8710>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E87F0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E8A90>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E8BE0>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E8CF8>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E8E48>, <blockchain.blockexplorer.Transaction object at 0x00000162C70E8F60>, <blockchain.blockexplorer.Transaction object at 0x00000162C70F0080>, <blockchain.blockexplorer.Transaction object at 0x00000162C70F0390>, <blockchain.blockexplorer.Transaction object a ...

# %%
# get the latest block
block = blockexplorer.get_latest_block()
block.height
# Out:
# 586168
